# %%
import glob

# %%
import os
import re
import inspect

def _get_parser_list(dirname):
    files = [f.replace('.py', '')
            for f in os.listdir(dirname) 
            if not f.startswith('__')]
            
    return files

def _import_parsers(parserfiles):
    m = re.compile('.+parser$', re.I)
    _modules = __import__('parsers',
            globals(),
            locals(),
            parserfiles,
            0) 

    _parsers = [(k, v) for k, v in inspect.getmembers(_modules)
            
            if inspect.ismodule(v) and m.match(k)]
    _classes = dict()
    for k, v in _parsers:
        _classes.update({k: v for k, v in inspect.getmembers(v)
                if inspect.isclass(v) and m.match(k)})
    
    return _classes

def load(dirname):
    parserfiles = _get_parser_list(dirname)
    return _import_parsers(parserfiles)

# %%
_p_uri = os.path.normpath(os.path.join(os.getcwd(), *['..','parsers']))
_p_files = _get_parser_list(dirname=_p_uri)
for _p in _p_files:
    print(_p)

#_p_classes = load(_p_uri)

#for k,v in _p_classes.items():
#    print(k , v)
# Out:
# base_parser
# dicom_parser
# excel_parser
# exif_parser
# ics_parser
# imagetext_parser
# name_parser
# pdf_parser
# powerpoint_parser
# word_parser
# zip_parser

# %%
_files = []
_paths = [
    os.path.join("D:\\", *["purge", "dicom", "DICOM Datasets"], "*.docx"),
    os.path.join("D:\\", *["purge", "dicom", "DICOM Datasets"], "*.doc"),
    os.path.join("D:\\", *["purge", "dicom", "DICOM Datasets"], "*.pdf")
]

#_base_folder = os.path.join("D:\\", *["purge", "dicom", "DICOM Datasets"], "*.docx") #", "
for _p in _paths:
    _files.extend(glob.glob(_p))

print(len(_files))
print(_files)
# Out:
# 57
# ['D:\\purge\\dicom\\DICOM Datasets\\22093011_KAMLESH W_O DULICHAND_BRAIN AND HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\22093014_SUNITA W_O ROTASH_BRAIN AND HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\22093015_SAURAV_BRAIN AND HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\22100114_NIRMAL W_O NARYAN_BRAIN AND HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Arvind kumar  b.docx', 'D:\\purge\\dicom\\DICOM Datasets\\BABY PARI 04 YRS----CT BRAIN.docx', 'D:\\purge\\dicom\\DICOM Datasets\\barji.docx', 'D:\\purge\\dicom\\DICOM Datasets\\BHAGOTI DEVI.docx', 'D:\\purge\\dicom\\DICOM Datasets\\CHETRAM CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\CT HEAD -SITA RAM.docx', 'D:\\purge\\dicom\\DICOM Datasets\\DEVI SAHAY.docx', 'D:\\purge\\dicom\\DICOM Datasets\\GOPAL SINGH CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Gulabi devi ct head.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Haneek.docx', 'D:\\purge\\dicom\\DICOM Datasets\\jagdish.docx', 'D:\\purge\\dicom\\DICOM Datasets\\JAYA KANWAR.docx', 'D:\\purge\\dicom\\DICOM Datasets\\KAMLA DEVI CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Kamlesh kumar  bb.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Kamlesh.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Kishan.docx', 'D:\\purge\\dicom\\DICOM Datasets\\KISHOR KUMAWAT CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\LALIT SONI CT BRAIN.docx', 'D:\\purge\\dicom\\DICOM Datasets\\MADAN LAL.docx', 'D:\\purge\\dicom\\DICOM Datasets\\MAHENDRA KUMAR CT EHAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Maina kumara.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Manju yadaw.docx', 'D:\\purge\\dicom\\DICOM Datasets\\MASTER PARAKARAM CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\MILAN CT BRAIN.docx', 'D:\\purge\\dicom\\DICOM Datasets\\NIKITA.docx', 'D:\\purge\\dicom\\DICOM Datasets\\PAWAN KUMAR.docx', 'D:\\purge\\dicom\\DICOM Datasets\\PHELODY HAKULYA.docx', 'D:\\purge\\dicom\\DICOM Datasets\\PHOOL CHAND  b.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Pooran mal  bn.docx', 'D:\\purge\\dicom\\DICOM Datasets\\PRAKASH CHAND.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Pramod kumar.docx', 'D:\\purge\\dicom\\DICOM Datasets\\PREM CHAND CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\RADHA DEVI.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Radhey shyam  b.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Raghu.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Rekha Kumawat.docx', 'D:\\purge\\dicom\\DICOM Datasets\\SANTOSH DEVI CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Savitri Devi.docx', 'D:\\purge\\dicom\\DICOM Datasets\\SITA DEVI CT EHAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Suman.docx', 'D:\\purge\\dicom\\DICOM Datasets\\Sunita -- bn.docx', 'D:\\purge\\dicom\\DICOM Datasets\\TARA CHAND CT HEAD.docx', 'D:\\purge\\dicom\\DICOM Datasets\\AVINASH CT BRAIN.doc', 'D:\\purge\\dicom\\DICOM Datasets\\MANBHARI DEVI.doc', 'D:\\purge\\dicom\\DICOM Datasets\\2210025_SURBHID_OSURESH_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\2210027_DHARAMVIR_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\2210028_KHUSHBOO D_O SHYAM_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\22100313_PANKAJ S_O RAJU_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\22100314_SHILPA W_O SOURABH_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\22100316_BHOOPRAM S_O SHRI CHAND_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\22100317_RAJU S_O LAKHAN LAL_BRAIN AND HEAD.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\22100319_KISHAN SINGH SOROUT_CT TEMPLATE 1.pdf', 'D:\\purge\\dicom\\DICOM Datasets\\22100320_NEERAJ_BRAIN AND HEAD.pdf']

# %%
import fitz

def get_pdfcontents(uri: str) -> dict:
    """ """
    data = []

    doc = fitz.open(uri)

    data = doc.get_toc(simple=True)

    return {
        "type": "toc",
        "toc": data
    }

def get_pdflines(uri: str) -> dict:
    """ """
    _doc = fitz.open(uri)
    _pages = {}
    _lines = []
    for _idx, _page in enumerate(_doc):
        _text = _page.get_text('text', sort=True, flags=2)
        if _text:
            _pages[_idx] = _text
            # the text is split on lines
            _lines.extend([x.strip() for x in _text.split("\n") if x.strip()])

    return {
        "type": "lines",
        "pages": _pages,
        "lines": _lines
    }

# %%
import docx2txt

def get_doxcontents(uri: str) -> dict:
    """ """
    text = docx2txt.process(uri)
    return {
        "type": "strings",
        "strings": text
    }

# %%
_funcs = {
    ".docx": get_doxcontents,
    ".pdf": get_pdflines
}

# %%
_data = {}
for _f in _files:
    print("FILE:\n\t",_f)
    _, _ext = os.path.splitext(_f)
    _func = _funcs.get(_ext.lower())
    if _func:
        _result = _func(uri=_f)
        #print("RESULT:\n\t",_result)
        if _result.get("type") == "strings":
            _lines =  [x.strip() for x in _result.get("strings","").split("\n") if x.strip()]
        elif _result.get("type") == "lines":
            _lines =  _result.get("lines",[])
                #list(filter(lambda item: item, _result.get("strings","").split("\n")))

        _data[_f] = {
            "contents": _result,
        }
        if len(_lines) > 0:
            _data[_f]["lines"] = _lines
# Out:
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22093011_KAMLESH W_O DULICHAND_BRAIN AND HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22093014_SUNITA W_O ROTASH_BRAIN AND HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22093015_SAURAV_BRAIN AND HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100114_NIRMAL W_O NARYAN_BRAIN AND HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Arvind kumar  b.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\BABY PARI 04 YRS----CT BRAIN.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\barji.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\BHAGOTI DEVI.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\CHETRAM CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\CT HEAD -SITA RAM.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\DEVI SAHAY.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\GOPAL SINGH CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Gulabi devi ct head.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Haneek.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\jagdish.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\JAYA KANWAR.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\KAMLA DEVI CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Kamlesh kumar  bb.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Kamlesh.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Kishan.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\KISHOR KUMAWAT CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\LALIT SONI CT BRAIN.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\MADAN LAL.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\MAHENDRA KUMAR CT EHAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Maina kumara.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Manju yadaw.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\MASTER PARAKARAM CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\MILAN CT BRAIN.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\NIKITA.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\PAWAN KUMAR.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\PHELODY HAKULYA.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\PHOOL CHAND  b.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Pooran mal  bn.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\PRAKASH CHAND.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Pramod kumar.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\PREM CHAND CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\RADHA DEVI.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Radhey shyam  b.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Raghu.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Rekha Kumawat.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\SANTOSH DEVI CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Savitri Devi.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\SITA DEVI CT EHAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Suman.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\Sunita -- bn.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\TARA CHAND CT HEAD.docx
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\AVINASH CT BRAIN.doc
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\MANBHARI DEVI.doc
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\2210025_SURBHID_OSURESH_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\2210027_DHARAMVIR_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\2210028_KHUSHBOO D_O SHYAM_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100313_PANKAJ S_O RAJU_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100314_SHILPA W_O SOURABH_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100316_BHOOPRAM S_O SHRI CHAND_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100317_RAJU S_O LAKHAN LAL_BRAIN AND HEAD.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100319_KISHAN SINGH SOROUT_CT TEMPLATE 1.pdf
# FILE:
# 	 D:\purge\dicom\DICOM Datasets\22100320_NEERAJ_BRAIN AND HEAD.pdf

# %%
_contents = {}
for _fp, _dv in _data.items():
    for _l in _dv.get("lines",[]):
        if _l.lower() not in _contents:
            _contents[_l.lower()] = 0
        _contents[_l.lower()] += 1

for _c in sorted(_contents.keys()):
    print(_c[:30], _contents.get(_c))
# Out:
# 011y 1
# 018y 1
# 022y 2
# 032y 1
# 034y 1
# 039y 1
# 040y 1
# 042y 1
# 046y 1
# 056y 1
# 062y 1
# 070y 1
# 1-oct-22 5
# 1/10/2022 12:35:05 pm 1
# 1/10/2022 1:02:27 pm 1
# 2-oct-22 4
# 2/10/2022 10:02:26 pm 1
# 2/10/2022 10:29:21 pm 1
# 2/10/2022 10:43:53 pm 1
# raghu 1
# raju s/o lakhan lal 1
# ref doctor 38
# ref. by 13
# rekha kumawat 1
# repeated or reassessed by othe 7
# report date 13
# rest of bilateral cerebral and 1
# rest of cerebral parenchyma ap 1
# rest of soft tissue and image  1
# rest of the brain parenchyma a 1
# santosh devi 1
# saurav 1
# savitri devi 1
# secretions are seen in left ma 1
# semiovale. 2
# sequelae of previous insult. 1
# sex 13
# shilpa w/o sourabh 1
# sigmoid shaped nasal septum no 3
# sita devi 1
# sita ram 1
# skin subcutaneous edema seen o 2
# small chronic infarct in right 1
# small chronic infarct is seen  1
# small ill-defined low attenuat 1
# small ill-defined low attenuat 1
# small parenchyma hematoma and  2
# soft tissue mucosal thickening 1
# soft tissue mucosal thickening 1
# soft tissue mucosal thickening 1
# soft tissue mucosal thickening 1
# soft tissue scalp swelling is  1
# soft tissue scalp swelling is  1
# soft tissue scalp swelling see 1
# soft tissue scalp swelling see 3
# soft tissue scalp swelling see 1
# soft tissue scalp swelling wit 1
# spaces. 1
# study date 13
# subarachnoid hemorrhage with t 1
# subarachnoid hemorrhage with t 1
# subdural hemorrhage along the  1
# subdural hemorrhage of maximum 1
# suboptimal study due to motion 4
# subtle linear fracture in righ 1
# subtle linear fracture seen in 1
# sulcal space hyperdensities ar 1
# sulcal space hyperdensities in 1
# sulcogyral and sylvian fissure 1
# suman 1
# sunita 1
# sunita w/o rotash 1
# surbhid/osuresh 1
# tara chand 1
# there is no shift of midline s 48
# there is prominent cortical su 2
# there is prominent ventricular 1
# there is prominent ventricular 5
# thin subdural hemorrhage along 1
# thin subdural hemorrhage is se 1
# this report is not valid for a 7
# this report is not valid for a 46
# ventricular system and cistern 6
# ventricular system and cistern 34
# ventricular system appears nor 1
# ventricular system with basal  4
# visualized bilateral mastoid a 6
# visualized mastoid air cells a 5
# visualized mastoid appears nor 4
# visualized orbits are normal. 6
# visualized para nasal sinuses  4
# visualized paranasal sinuses a 4
# visualized paranasal sinuses a 2
# way can this report be utilize 7
# yrs 40
# yrs. 2
# • 23

# %%
import re

_fields = [
    "age",
    "date",
    "gender",
    "patient id",
    "patient name",
    "ref doctor",
    "ref. by",
    "report date",
    "sex",
    "study date",
]

_regs = {
    "notice": re.compile("^(this report is not valid.*$)", re.IGNORECASE),
    "scan": re.compile("(^.*scan of brain.*$)", re.IGNORECASE),
    #"impression": re.compile("^impression:(.*)$", re.IGNORECASE),
    #"observations": re.compile("^observations:(.*)$", re.IGNORECASE),
    #"protocol": re.compile("^protocol:(.*)$", re.IGNORECASE),
    #"disclaimer": re.compile("^disclaimer:(.*)$", re.IGNORECASE),
    #"advice": re.compile("^advice:(.*)$", re.IGNORECASE),
    "advice": re.compile("^(please correlate.*)$", re.IGNORECASE),
    "__misc": re.compile("^([a-zA-Z]+):(.*)$", re.IGNORECASE),
}

_mappings = {
    "ref. by": "referral",
    "ref doctor": "referral",
    "adv": "advice"
}

# %%
_test = "ADVICE:  Please Correlate Clinically"
for _rl, _re in _regs.items():
    _m = _re.match(_test)
    print(_m)
    if _m:
        if len(_m.groups()) > 1:
            print(_m.group(1).strip().lower()," -> ", _m.group(2).strip())
        else:
            print(_m.group(1).strip())
# Out:
# None
# None
# None
# <re.Match object; span=(0, 36), match='ADVICE:  Please Correlate Clinically'>
# advice  ->  Please Correlate Clinically

# %%
#_uri = r"D:\purge\dicom\DICOM Datasets\2210025_SURBHID_OSURESH_BRAIN AND HEAD.pdf"
#_uri = r"D:\purge\dicom\DICOM Datasets\22100320_NEERAJ_BRAIN AND HEAD.pdf"
#_uri = r"D:\purge\dicom\DICOM Datasets\22093011_KAMLESH W_O DULICHAND_BRAIN AND HEAD.docx"
_uri = r"D:\purge\dicom\DICOM Datasets\BABY PARI 04 YRS----CT BRAIN.docx"

# %%
# process the fields and extract to a text...
for _fp, _dv in _data.items():
    _dout = (_uri and _fp == _uri)

    _record = {}
    _k = None
    _ls = []
    for _l in _dv.get("lines",[]):
        print(f"Line: {_l}") if _dout else None
        _mfnd = False
        if _l.lower() in _fields:
            if _k and _ls:
                _record[_k] = '\n'.join(_ls)
                print(f"L Field: {_k} {_ls}") if _dout else None
            _k = _l.lower()
            _ls = []
            print(f"L New: {_k}") if _dout else None
            continue
        else:
            for _rl, _re in _regs.items():
                _m = _re.match(_l)
                print(f"M Reg: {_k} {_m}") if _dout else None
                if _m:
                    if len(_m.groups()) > 1:
                        _nk = _m.group(1).strip().lower()
                        _nl = _m.group(2).strip()
                    else:
                        _nk = None
                        _nl = _m.group(1).strip()

                    if _k and _ls:
                        _record[_k] = '\n'.join(_ls)
                        print(f"M Field: {_k} {_ls}") if _dout else None

                    _k = _nk if _nk else _rl
                    _ls = []
                    print(f"M New: {_k}") if _dout else None
                    _ls.append(_nl)
                    _mfnd = True
                    continue

        if _mfnd is True:
            continue

        if _k:
            _ls.append(_l)
            print(f"G Field: {_k} {_ls}") if _dout else None

    if _k and _ls:
        _record[_k] = '\n'.join(_ls)    

    #print(f"File: {_fp}\n\t\t{_record}")
    _data[_fp]["record"] = _record
# Out:
# Line: Patient ID
# L New: patient id
# Line: Patient Name
# L New: patient name
# Line: Age
# L New: age
# Line: yrs
# M Reg: age None
# M Reg: age None
# M Reg: age None
# M Reg: age None
# G Field: age ['yrs']
# Line: Date
# L Field: age ['yrs']
# L New: date
# Line: 2-Oct-22
# M Reg: date None
# M Reg: date None
# M Reg: date None
# M Reg: date None
# G Field: date ['2-Oct-22']
# Line: Gender
# L Field: date ['2-Oct-22']
# L New: gender
# Line: Ref Doctor
# L New: ref doctor
# Line: CT SCAN OF BRAIN (PLAIN)
# M Reg: ref doctor None
# M Reg: ref doctor <re.Match object; span=(0, 24), match='CT SCAN OF BRAIN (PLAIN)'>
# M New: scan
# M Reg: scan None
# M Reg: scan None
# Line: Suboptimal study due to motion blur. Scan reported with these limitations.
# M Reg: scan None
# M Reg: scan None
# M Reg: scan None
# M Reg: scan None
# G Field: scan ['CT SCAN OF BRAIN (PLAIN)', 'Suboptimal study due to motion blur. Scan reported with these limitations.']
# Line: OBSERVATIONS:
# M Reg: scan None
# M Reg: scan None
# M Reg: scan None
# M Reg: scan <re.Match object; span=(0, 13), match='OBSERVATIONS:'>
# M Field: scan ['CT SCAN OF BRAIN (PLAIN)', 'Suboptimal study due to motion blur. Scan reported with these limitations.']
# M New: observations
# Line: Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.']
# Line: Bilateral basal ganglia and thalami are normal.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.']
# Line: Cerebellar hemispheres and brain stem   are showing normal attenuation values.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.']
# Line: Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.']
# Line: No mass effect or midline shift.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.']
# Line: no obvious calcification, mass lesion or hemorrhage is seen.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.']
# Line: Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.', 'Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.']
# Line: No obvious skull fracture is seen.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.', 'Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.', 'No obvious skull fracture is seen.']
# Line: Visualized paranasal sinuses are normal.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.', 'Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.', 'No obvious skull fracture is seen.', 'Visualized paranasal sinuses are normal.']
# Line: Visualized mastoid air cells and orbits are normal.
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# G Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.', 'Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.', 'No obvious skull fracture is seen.', 'Visualized paranasal sinuses are normal.', 'Visualized mastoid air cells and orbits are normal.']
# Line: IMPRESSION: CT FINDINGS ARE SUGGESTIVE OF
# M Reg: observations None
# M Reg: observations None
# M Reg: observations None
# M Reg: observations <re.Match object; span=(0, 41), match='IMPRESSION: CT FINDINGS ARE SUGGESTIVE OF'>
# M Field: observations ['', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.', 'Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.', 'No obvious skull fracture is seen.', 'Visualized paranasal sinuses are normal.', 'Visualized mastoid air cells and orbits are normal.']
# M New: impression
# Line: No Significant abnormality is noted in brain parenchyma.
# M Reg: impression None
# M Reg: impression None
# M Reg: impression None
# M Reg: impression None
# G Field: impression ['CT FINDINGS ARE SUGGESTIVE OF', 'No Significant abnormality is noted in brain parenchyma.']
# Line: Extracranial soft tissue swelling is seen over left occipito-parietal region.
# M Reg: impression None
# M Reg: impression None
# M Reg: impression None
# M Reg: impression None
# G Field: impression ['CT FINDINGS ARE SUGGESTIVE OF', 'No Significant abnormality is noted in brain parenchyma.', 'Extracranial soft tissue swelling is seen over left occipito-parietal region.']
# Line: ADVICE:  Please Correlate Clinically
# M Reg: impression None
# M Reg: impression None
# M Reg: impression None
# M Reg: impression <re.Match object; span=(0, 36), match='ADVICE:  Please Correlate Clinically'>
# M Field: impression ['CT FINDINGS ARE SUGGESTIVE OF', 'No Significant abnormality is noted in brain parenchyma.', 'Extracranial soft tissue swelling is seen over left occipito-parietal region.']
# M New: advice
# Line: This Report is not valid for any medico legal purpose. This report is prepared on the basis of digital DICOM images transmitted via internet without identification of patient, not on the films or plates provided to the patient.
# M Reg: advice <re.Match object; span=(0, 227), match='This Report is not valid for any medico legal pur>
# M Field: advice ['Please Correlate Clinically']
# M New: notice
# M Reg: notice None
# M Reg: notice None
# M Reg: notice None
# Line: Disclaimer: - It is an online interpretation of medical imaging based on clinical data. All modern machines/procedures have their own limitation. If there is any clinical discrepancy, this investigation may be repeated or reassessed by other tests. Patient’s identification in online reporting is not established, so in no way can this report be utilized for any medico legal purpose. In case of any discrepancy due to typing error or machinery error please get it rectified immediately*.
# M Reg: notice None
# M Reg: notice None
# M Reg: notice None
# M Reg: notice <re.Match object; span=(0, 488), match='Disclaimer: -\xa0It is an online interpretation o>
# M Field: notice ['This Report is not valid for any medico legal purpose. This report is prepared on the basis of digital DICOM images transmitted via internet without identification of patient,\xa0not on the films or plates provided to the patient.']
# M New: disclaimer

# %%
for _dr, _dv in _data.get(_uri,{}).items():
    #print(f"{_dr}: ==>\n\t {_dv}")
    print(f"{_dr}: ==>")
    if "record" in _dv:
        for _fk, _fv in _dv.get("record", {}).items():
            print(f"\t{_fk}:\t{+fv}")

    elif "lines" in _dv:
        for _lv in _dv.get("lines", []):
            print(f"\t|{_lv}")

    else:
        print(f"\t:{_dv}")
# Out:
# contents: ==>
# 	:{'type': 'strings', 'strings': 'Patient ID\n\n\t\n\n\tPatient Name\n\n\t\n\n\tAge\n\n\tyrs\n\n\tDate\n\n\t2-Oct-22\n\n\tGender\n\n\t\n\n\tRef Doctor\n\n\t\n\n\n\nCT SCAN OF BRAIN (PLAIN)\n\n\n\nSuboptimal study due to motion blur. Scan reported with these limitations. \n\n\n\nOBSERVATIONS:\n\nCerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.\n\nBilateral basal ganglia and thalami are normal.\n\nCerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.\n\nVentricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized. \n\nNo mass effect or midline shift.\n\nno obvious calcification, mass lesion or hemorrhage is seen.\n\nExtra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.\n\nNo obvious skull fracture is seen. \n\nVisualized paranasal sinuses are normal. \n\nVisualized mastoid air cells and orbits are normal.\n\n\n\nIMPRESSION: CT FINDINGS ARE SUGGESTIVE OF \n\nNo Significant abnormality is noted in brain parenchyma.  \n\nExtracranial soft tissue swelling is seen over left occipito-parietal region. \n\nADVICE:  Please Correlate Clinically \n\n\n\n\n\nThis Report is not valid for any medico legal purpose. This report is prepared on the basis of digital DICOM images transmitted via internet without identification of patient,\xa0not on the films or plates provided to the patient.                                      \n\n\n\nDisclaimer: -\xa0It is an online interpretation of medical imaging based on clinical data. All modern machines/procedures have their own limitation. If there is any clinical discrepancy, this investigation may be repeated or reassessed by other tests. Patient’s identification in online reporting is not established, so in no way can this report be utilized for any medico legal purpose. In case of any discrepancy due to typing error or machinery error please get it rectified immediately*.'}
# lines: ==>
# 	:['Patient ID', 'Patient Name', 'Age', 'yrs', 'Date', '2-Oct-22', 'Gender', 'Ref Doctor', 'CT SCAN OF BRAIN (PLAIN)', 'Suboptimal study due to motion blur. Scan reported with these limitations.', 'OBSERVATIONS:', 'Cerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.', 'Bilateral basal ganglia and thalami are normal.', 'Cerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.', 'Ventricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.', 'No mass effect or midline shift.', 'no obvious calcification, mass lesion or hemorrhage is seen.', 'Extra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.', 'No obvious skull fracture is seen.', 'Visualized paranasal sinuses are normal.', 'Visualized mastoid air cells and orbits are normal.', 'IMPRESSION: CT FINDINGS ARE SUGGESTIVE OF', 'No Significant abnormality is noted in brain parenchyma.', 'Extracranial soft tissue swelling is seen over left occipito-parietal region.', 'ADVICE:  Please Correlate Clinically', 'This Report is not valid for any medico legal purpose. This report is prepared on the basis of digital DICOM images transmitted via internet without identification of patient,\xa0not on the films or plates provided to the patient.', 'Disclaimer: -\xa0It is an online interpretation of medical imaging based on clinical data. All modern machines/procedures have their own limitation. If there is any clinical discrepancy, this investigation may be repeated or reassessed by other tests. Patient’s identification in online reporting is not established, so in no way can this report be utilized for any medico legal purpose. In case of any discrepancy due to typing error or machinery error please get it rectified immediately*.']
# record: ==>
# 	:{'age': 'yrs', 'date': '2-Oct-22', 'scan': 'CT SCAN OF BRAIN (PLAIN)\nSuboptimal study due to motion blur. Scan reported with these limitations.', 'observations': '\nCerebral parenchyma shows normal density & gray white matter differentiation. Septum pellucidum and falx cerebri are seen in midline.\nBilateral basal ganglia and thalami are normal.\nCerebellar hemispheres and brain stem  \xa0are showing normal attenuation values.\nVentricular system with basal cisterns & cerebral cortical sulci including sylvian fissures are normally visualized.\nNo mass effect or midline shift.\nno obvious calcification, mass lesion or hemorrhage is seen.\nExtra-axial spaces are clear. No significant subdural / extradural collection, hematoma or mass lesion is observed.\nNo obvious skull fracture is seen.\nVisualized paranasal sinuses are normal.\nVisualized mastoid air cells and orbits are normal.', 'impression': 'CT FINDINGS ARE SUGGESTIVE OF\nNo Significant abnormality is noted in brain parenchyma.\nExtracranial soft tissue swelling is seen over left occipito-parietal region.', 'advice': 'Please Correlate Clinically', 'notice': 'This Report is not valid for any medico legal purpose. This report is prepared on the basis of digital DICOM images transmitted via internet without identification of patient,\xa0not on the films or plates provided to the patient.', 'disclaimer': '-\xa0It is an online interpretation of medical imaging based on clinical data. All modern machines/procedures have their own limitation. If there is any clinical discrepancy, this investigation may be repeated or reassessed by other tests. Patient’s identification in online reporting is not established, so in no way can this report be utilized for any medico legal purpose. In case of any discrepancy due to typing error or machinery error please get it rectified immediately*.'}

# %%
fields = set()
fields.add("file")
rows = []

for _dr, _dv in _data.items():
    #print(f"{_dr}: ==>\n\t {_dv}")
    #print(f"{_dr}: ==>")
    if "record" in _dv:
        row = {
            "file": _dr
        }
        for _fk, _fv in _dv.get("record", {}).items():
            _uk = _mappings.get(_fk)
            _fk = _uk if _uk else _fk
            row.setdefault(_fk, _fv)
            fields.add(_fk)
            #if _fk in ["adv","advice"]:
            #    print(f"\t{_fk}: {_fv}")
        rows.append(row)

    elif "lines" in _dv:
        for _lv in _dv.get("lines", []):
            print(f"\t|{_lv}")

    else:
        print(f"\t:{_dv}")

print(fields)
# Out:
# {'patient id', 'gender', 'file', 'report date', 'scan', 'disclaimer', 'referral', 'date', 'impression', 'study date', 'notice', 'protocol', 'sex', 'patient name', 'advice', 'observations', 'age'}

# %%
import csv

with open('DICOMReports.csv', 'w', newline='') as output_file:
    dict_writer = csv.DictWriter(output_file, list(fields))
    dict_writer.writeheader()
    dict_writer.writerows(rows)
